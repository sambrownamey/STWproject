# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

pd.options.display.max_columns = 80

# %%
# %run stwpy/complaints_reader.py
# Out:
# C:\Users\142796\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\magics\execution.py:728: DtypeWarning: Columns (2,23,24,25,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   exit_ignore=exit_ignore)

# %%
from stwpy.complaints_reader import ComplaintsDFWithRegions

# %%
ComplaintsDFWithRegions.tail(10)
# Out:
#                   DateTime  ComplaintRef Legal Entity Number  Year     FYTD  \
# 105382 2016-05-26 18:17:17    2002563753           121432004  2016  2016-17
# 105383 2016-05-26 18:43:10    2002563746           598042715  2016  2016-17
# 105384 2016-05-26 18:14:48    2002563741           823212931  2016  2016-17
# 105385 2016-05-26 18:14:45    2002563740           121114514  2016  2016-17
# 105386 2016-05-26 18:14:28    2002563739           991006129  2016  2016-17
# 105387 2016-05-26 18:13:53    2002563738           721003032  2016  2016-17
# 105388 2016-05-26 17:59:02    2002563732           463012208  2016  2016-17
# 105389 2016-05-26 18:06:05    2002563707           121256118  2016  2016-17
# 105390 2016-05-26 17:54:07    2002563687           432002895  2016  2016-17
# 105391 2016-05-27 12:46:11    2002564470           456006554  2016  2016-17
#
#         Month        Date      Time Postcode         X         Y    DMA  \
# ...

# %%
len(ComplaintsDFWithRegions)
# Out:
# 105392

# %%
ComplaintsDFWithRegions['DateTime'].hist(bins = 30)
plt.show()
